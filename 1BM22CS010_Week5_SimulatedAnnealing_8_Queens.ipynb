# %%
import random
import math

n=8

def no_of_conflicts(board):
    conflicts = 0
    n = len(board)
    for i in range(n):
        for j in range(i + 1, n):
            if board[i] == board[j] or abs(board[i] - board[j]) == j - i:
                conflicts += 1
    return conflicts

def initialize(n):
    return [random.randint(0, n - 1) for _ in range(n)]

def simulated_annealing(n, max_iterations=10000, initial_temp=100, cooling_rate=0.99):
    board = initialize(n)
    current_conflicts = no_of_conflicts(board)
    temperature = initial_temp

    for iteration in range(max_iterations):
        if current_conflicts == 0:
            print(f"Iteration {iteration}: Solution found!")
            print("Board Position:", board)
            return board

        row = random.randint(0, n - 1)
        new_col = random.randint(0, n - 1)
        while new_col == board[row]:
            new_col = random.randint(0, n - 1)

        new_board = board[:]
        new_board[row] = new_col
        new_conflicts = no_of_conflicts(new_board)
        delta_conflicts = new_conflicts - current_conflicts
        if delta_conflicts < 0 or math.exp(-delta_conflicts / temperature) > random.random():
            board, current_conflicts = new_board, new_conflicts
        print(f"Iteration {iteration}: Temperature={temperature:.2f}, Current Conflicts={current_conflicts}, "
              f"Delta Conflicts={delta_conflicts}, New Position for Row {row} -> Column {new_col}")
        print("Board Position:", board)
        temperature *= cooling_rate

    print("No solution found within the maximum iterations.")
    return None

solution = simulated_annealing(n)
if solution:
    print("Final Solution:", solution)
else:
    print("No solution found within the maximum iterations.")
# Out:
# Iteration 0: Temperature=100.00, Current Conflicts=12, Delta Conflicts=-2, New Position for Row 0 -> Column 6
# Board Position: [6, 1, 6, 1, 4, 4, 6, 7]
# Iteration 1: Temperature=99.00, Current Conflicts=11, Delta Conflicts=-1, New Position for Row 3 -> Column 0
# Board Position: [6, 1, 6, 0, 4, 4, 6, 7]
# Iteration 2: Temperature=98.01, Current Conflicts=7, Delta Conflicts=-4, New Position for Row 4 -> Column 2
# Board Position: [6, 1, 6, 0, 2, 4, 6, 7]
# Iteration 3: Temperature=97.03, Current Conflicts=7, Delta Conflicts=0, New Position for Row 1 -> Column 0
# Board Position: [6, 0, 6, 0, 2, 4, 6, 7]
# Iteration 4: Temperature=96.06, Current Conflicts=8, Delta Conflicts=1, New Position for Row 5 -> Column 1
# Board Position: [6, 0, 6, 0, 2, 1, 6, 7]
# Iteration 5: Temperature=95.10, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 1 -> Column 3
# Board Position: [6, 3, 6, 0, 2, 1, 6, 7]
# Iteration 6: Temperature=94.15, Current Conflicts=4, Delta Conflicts=-3, New Position for Row 0 -> Column 1
# Board Position: [1, 3, 6, 0, 2, 1, 6, 7]
# Iteration 7: Temperature=93.21, Current Conflicts=4, Delta Conflicts=0, New Position for Row 7 -> Column 4
# Board Position: [1, 3, 6, 0, 2, 1, 6, 4]
# Iteration 8: Temperature=92.27, Current Conflicts=6, Delta Conflicts=2, New Position for Row 6 -> Column 2
# Board Position: [1, 3, 6, 0, 2, 1, 2, 4]
# Iteration 9: Temperature=91.35, Current Conflicts=9, Delta Conflicts=3, New Position for Row 7 -> Column 1
# Board Position: [1, 3, 6, 0, 2, 1, 2, 1]
# Iteration 10: Temperature=90.44, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 5 -> Column 2
# Board Position: [1, 3, 6, 0, 2, 2, 2, 1]
# Iteration 11: Temperature=89.53, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 6 -> Column 3
# Board Position: [1, 3, 6, 0, 2, 2, 3, 1]
# Iteration 12: Temperature=88.64, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 0
# Board Position: [1, 3, 6, 0, 2, 2, 3, 0]
# Iteration 13: Temperature=87.75, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 1 -> Column 4
# Board Position: [1, 4, 6, 0, 2, 2, 3, 0]
# Iteration 14: Temperature=86.87, Current Conflicts=6, Delta Conflicts=0, New Position for Row 3 -> Column 2
# Board Position: [1, 4, 6, 2, 2, 2, 3, 0]
# Iteration 15: Temperature=86.01, Current Conflicts=8, Delta Conflicts=2, New Position for Row 0 -> Column 5
# Board Position: [5, 4, 6, 2, 2, 2, 3, 0]
# Iteration 16: Temperature=85.15, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 6 -> Column 7
# Board Position: [5, 4, 6, 2, 2, 2, 7, 0]
# Iteration 17: Temperature=84.29, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 4
# Board Position: [5, 4, 6, 2, 4, 2, 7, 0]
# Iteration 18: Temperature=83.45, Current Conflicts=9, Delta Conflicts=2, New Position for Row 6 -> Column 4
# Board Position: [5, 4, 6, 2, 4, 2, 4, 0]
# Iteration 19: Temperature=82.62, Current Conflicts=10, Delta Conflicts=1, New Position for Row 7 -> Column 2
# Board Position: [5, 4, 6, 2, 4, 2, 4, 2]
# Iteration 20: Temperature=81.79, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 4, 6, 2, 4, 2, 4, 2]
# Iteration 21: Temperature=80.97, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 3 -> Column 3
# Board Position: [0, 4, 6, 3, 4, 2, 4, 2]
# Iteration 22: Temperature=80.16, Current Conflicts=8, Delta Conflicts=0, New Position for Row 1 -> Column 7
# Board Position: [0, 7, 6, 3, 4, 2, 4, 2]
# Iteration 23: Temperature=79.36, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 6
# Board Position: [0, 7, 6, 3, 4, 2, 4, 6]
# Iteration 24: Temperature=78.57, Current Conflicts=8, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [0, 7, 6, 3, 4, 2, 5, 6]
# Iteration 25: Temperature=77.78, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 7
# Board Position: [0, 7, 6, 7, 4, 2, 5, 6]
# Iteration 26: Temperature=77.00, Current Conflicts=9, Delta Conflicts=1, New Position for Row 5 -> Column 0
# Board Position: [0, 7, 6, 7, 4, 0, 5, 6]
# Iteration 27: Temperature=76.23, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 4 -> Column 5
# Board Position: [0, 7, 6, 7, 5, 0, 5, 6]
# Iteration 28: Temperature=75.47, Current Conflicts=9, Delta Conflicts=2, New Position for Row 5 -> Column 4
# Board Position: [0, 7, 6, 7, 5, 4, 5, 6]
# Iteration 29: Temperature=74.72, Current Conflicts=12, Delta Conflicts=3, New Position for Row 0 -> Column 6
# Board Position: [6, 7, 6, 7, 5, 4, 5, 6]
# Iteration 30: Temperature=73.97, Current Conflicts=9, Delta Conflicts=-3, New Position for Row 1 -> Column 1
# Board Position: [6, 1, 6, 7, 5, 4, 5, 6]
# Iteration 31: Temperature=73.23, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 2 -> Column 5
# Board Position: [6, 1, 5, 7, 5, 4, 5, 6]
# Iteration 32: Temperature=72.50, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 7 -> Column 0
# Board Position: [6, 1, 5, 7, 5, 4, 5, 0]
# Iteration 33: Temperature=71.77, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 6 -> Column 7
# Board Position: [6, 1, 5, 7, 5, 4, 7, 0]
# Iteration 34: Temperature=71.06, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 7
# Board Position: [6, 1, 5, 7, 7, 4, 7, 0]
# Iteration 35: Temperature=70.34, Current Conflicts=5, Delta Conflicts=0, New Position for Row 6 -> Column 0
# Board Position: [6, 1, 5, 7, 7, 4, 0, 0]
# Iteration 36: Temperature=69.64, Current Conflicts=5, Delta Conflicts=0, New Position for Row 7 -> Column 4
# Board Position: [6, 1, 5, 7, 7, 4, 0, 4]
# Iteration 37: Temperature=68.94, Current Conflicts=5, Delta Conflicts=0, New Position for Row 1 -> Column 2
# Board Position: [6, 2, 5, 7, 7, 4, 0, 4]
# Iteration 38: Temperature=68.26, Current Conflicts=7, Delta Conflicts=2, New Position for Row 3 -> Column 0
# Board Position: [6, 2, 5, 0, 7, 4, 0, 4]
# Iteration 39: Temperature=67.57, Current Conflicts=7, Delta Conflicts=2, New Position for Row 1 -> Column 0
# Board Position: [6, 2, 5, 0, 7, 4, 0, 4]
# Iteration 40: Temperature=66.90, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 3
# Board Position: [6, 2, 5, 0, 3, 4, 0, 4]
# Iteration 41: Temperature=66.23, Current Conflicts=7, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [6, 2, 5, 0, 3, 0, 0, 4]
# Iteration 42: Temperature=65.57, Current Conflicts=7, Delta Conflicts=0, New Position for Row 2 -> Column 2
# Board Position: [6, 2, 2, 0, 3, 0, 0, 4]
# Iteration 43: Temperature=64.91, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 3
# Board Position: [6, 2, 2, 0, 3, 0, 0, 3]
# Iteration 44: Temperature=64.26, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 5 -> Column 4
# Board Position: [6, 2, 2, 0, 3, 4, 0, 3]
# Iteration 45: Temperature=63.62, Current Conflicts=7, Delta Conflicts=1, New Position for Row 1 -> Column 3
# Board Position: [6, 3, 2, 0, 3, 4, 0, 3]
# Iteration 46: Temperature=62.98, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 4 -> Column 1
# Board Position: [6, 3, 2, 0, 1, 4, 0, 3]
# Iteration 47: Temperature=62.35, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 1 -> Column 6
# Board Position: [6, 6, 2, 0, 1, 4, 0, 3]
# Iteration 48: Temperature=61.73, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 7
# Board Position: [6, 6, 2, 0, 1, 7, 0, 3]
# Iteration 49: Temperature=61.11, Current Conflicts=8, Delta Conflicts=4, New Position for Row 5 -> Column 2
# Board Position: [6, 6, 2, 0, 1, 2, 0, 3]
# Iteration 50: Temperature=60.50, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 3 -> Column 6
# Board Position: [6, 6, 2, 6, 1, 2, 0, 3]
# Iteration 51: Temperature=59.90, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 6, 2, 6, 1, 2, 0, 3]
# Iteration 52: Temperature=59.30, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 2
# Board Position: [2, 6, 2, 6, 1, 2, 0, 3]
# Iteration 53: Temperature=58.70, Current Conflicts=7, Delta Conflicts=1, New Position for Row 3 -> Column 1
# Board Position: [2, 6, 2, 1, 1, 2, 0, 3]
# Iteration 54: Temperature=58.12, Current Conflicts=10, Delta Conflicts=3, New Position for Row 4 -> Column 2
# Board Position: [2, 6, 2, 1, 2, 2, 0, 3]
# Iteration 55: Temperature=57.54, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 2 -> Column 6
# Board Position: [2, 6, 6, 1, 2, 2, 0, 3]
# Iteration 56: Temperature=56.96, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 5 -> Column 7
# Board Position: [2, 6, 6, 1, 2, 7, 0, 3]
# Iteration 57: Temperature=56.39, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 4 -> Column 3
# Board Position: [2, 6, 6, 1, 3, 7, 0, 3]
# Iteration 58: Temperature=55.83, Current Conflicts=4, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [2, 6, 6, 1, 3, 0, 0, 3]
# Iteration 59: Temperature=55.27, Current Conflicts=6, Delta Conflicts=2, New Position for Row 4 -> Column 6
# Board Position: [2, 6, 6, 1, 6, 0, 0, 3]
# Iteration 60: Temperature=54.72, Current Conflicts=8, Delta Conflicts=2, New Position for Row 6 -> Column 1
# Board Position: [2, 6, 6, 1, 6, 0, 1, 3]
# Iteration 61: Temperature=54.17, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 0
# Board Position: [2, 6, 6, 0, 6, 0, 1, 3]
# Iteration 62: Temperature=53.63, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 1 -> Column 0
# Board Position: [2, 0, 6, 0, 6, 0, 1, 3]
# Iteration 63: Temperature=53.09, Current Conflicts=7, Delta Conflicts=0, New Position for Row 0 -> Column 7
# Board Position: [7, 0, 6, 0, 6, 0, 1, 3]
# Iteration 64: Temperature=52.56, Current Conflicts=8, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [6, 0, 6, 0, 6, 0, 1, 3]
# Iteration 65: Temperature=52.03, Current Conflicts=8, Delta Conflicts=0, New Position for Row 1 -> Column 7
# Board Position: [6, 7, 6, 0, 6, 0, 1, 3]
# Iteration 66: Temperature=51.51, Current Conflicts=8, Delta Conflicts=0, New Position for Row 4 -> Column 0
# Board Position: [6, 7, 6, 0, 0, 0, 1, 3]
# Iteration 67: Temperature=51.00, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 5 -> Column 7
# Board Position: [6, 7, 6, 0, 0, 7, 1, 3]
# Iteration 68: Temperature=50.49, Current Conflicts=8, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [6, 7, 6, 0, 0, 3, 1, 3]
# Iteration 69: Temperature=49.98, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 7 -> Column 4
# Board Position: [6, 7, 6, 0, 0, 3, 1, 4]
# Iteration 70: Temperature=49.48, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 1 -> Column 2
# Board Position: [6, 2, 6, 0, 0, 3, 1, 4]
# Iteration 71: Temperature=48.99, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 5 -> Column 5
# Board Position: [6, 2, 6, 0, 0, 5, 1, 4]
# Iteration 72: Temperature=48.50, Current Conflicts=7, Delta Conflicts=3, New Position for Row 6 -> Column 6
# Board Position: [6, 2, 6, 0, 0, 5, 6, 4]
# Iteration 73: Temperature=48.01, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 2 -> Column 7
# Board Position: [6, 2, 7, 0, 0, 5, 6, 4]
# Iteration 74: Temperature=47.53, Current Conflicts=5, Delta Conflicts=0, New Position for Row 6 -> Column 7
# Board Position: [6, 2, 7, 0, 0, 5, 7, 4]
# Iteration 75: Temperature=47.06, Current Conflicts=5, Delta Conflicts=0, New Position for Row 1 -> Column 5
# Board Position: [6, 5, 7, 0, 0, 5, 7, 4]
# Iteration 76: Temperature=46.59, Current Conflicts=7, Delta Conflicts=2, New Position for Row 0 -> Column 4
# Board Position: [4, 5, 7, 0, 0, 5, 7, 4]
# Iteration 77: Temperature=46.12, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 6 -> Column 1
# Board Position: [4, 5, 7, 0, 0, 5, 1, 4]
# Iteration 78: Temperature=45.66, Current Conflicts=7, Delta Conflicts=1, New Position for Row 6 -> Column 7
# Board Position: [4, 5, 7, 0, 0, 5, 7, 4]
# Iteration 79: Temperature=45.20, Current Conflicts=8, Delta Conflicts=1, New Position for Row 2 -> Column 6
# Board Position: [4, 5, 6, 0, 0, 5, 7, 4]
# Iteration 80: Temperature=44.75, Current Conflicts=8, Delta Conflicts=0, New Position for Row 2 -> Column 5
# Board Position: [4, 5, 5, 0, 0, 5, 7, 4]
# Iteration 81: Temperature=44.30, Current Conflicts=10, Delta Conflicts=2, New Position for Row 4 -> Column 5
# Board Position: [4, 5, 5, 0, 5, 5, 7, 4]
# Iteration 82: Temperature=43.86, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 1 -> Column 1
# Board Position: [4, 1, 5, 0, 5, 5, 7, 4]
# Iteration 83: Temperature=43.42, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 2 -> Column 6
# Board Position: [4, 1, 6, 0, 5, 5, 7, 4]
# Iteration 84: Temperature=42.99, Current Conflicts=6, Delta Conflicts=0, New Position for Row 6 -> Column 1
# Board Position: [4, 1, 6, 0, 5, 5, 1, 4]
# Iteration 85: Temperature=42.56, Current Conflicts=6, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [4, 1, 6, 0, 5, 0, 1, 4]
# Iteration 86: Temperature=42.13, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 6 -> Column 2
# Board Position: [4, 1, 6, 0, 5, 0, 2, 4]
# Iteration 87: Temperature=41.71, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 0 -> Column 6
# Board Position: [6, 1, 6, 0, 5, 0, 2, 4]
# Iteration 88: Temperature=41.29, Current Conflicts=4, Delta Conflicts=0, New Position for Row 2 -> Column 1
# Board Position: [6, 1, 1, 0, 5, 0, 2, 4]
# Iteration 89: Temperature=40.88, Current Conflicts=5, Delta Conflicts=1, New Position for Row 1 -> Column 4
# Board Position: [6, 4, 1, 0, 5, 0, 2, 4]
# Iteration 90: Temperature=40.47, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 1 -> Column 1
# Board Position: [6, 1, 1, 0, 5, 0, 2, 4]
# Iteration 91: Temperature=40.07, Current Conflicts=7, Delta Conflicts=3, New Position for Row 6 -> Column 3
# Board Position: [6, 1, 1, 0, 5, 0, 3, 4]
# Iteration 92: Temperature=39.67, Current Conflicts=7, Delta Conflicts=0, New Position for Row 2 -> Column 4
# Board Position: [6, 1, 4, 0, 5, 0, 3, 4]
# Iteration 93: Temperature=39.27, Current Conflicts=10, Delta Conflicts=3, New Position for Row 1 -> Column 4
# Board Position: [6, 4, 4, 0, 5, 0, 3, 4]
# Iteration 94: Temperature=38.88, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 5 -> Column 7
# Board Position: [6, 4, 4, 0, 5, 7, 3, 4]
# Iteration 95: Temperature=38.49, Current Conflicts=11, Delta Conflicts=2, New Position for Row 5 -> Column 6
# Board Position: [6, 4, 4, 0, 5, 6, 3, 4]
# Iteration 96: Temperature=38.10, Current Conflicts=8, Delta Conflicts=-3, New Position for Row 2 -> Column 2
# Board Position: [6, 4, 2, 0, 5, 6, 3, 4]
# Iteration 97: Temperature=37.72, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 7 -> Column 2
# Board Position: [6, 4, 2, 0, 5, 6, 3, 2]
# Iteration 98: Temperature=37.35, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 5 -> Column 7
# Board Position: [6, 4, 2, 0, 5, 7, 3, 2]
# Iteration 99: Temperature=36.97, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 6
# Board Position: [6, 4, 2, 0, 6, 7, 3, 2]
# Iteration 100: Temperature=36.60, Current Conflicts=8, Delta Conflicts=3, New Position for Row 2 -> Column 4
# Board Position: [6, 4, 4, 0, 6, 7, 3, 2]
# Iteration 101: Temperature=36.24, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 4, 4, 0, 6, 7, 3, 2]
# Iteration 102: Temperature=35.87, Current Conflicts=8, Delta Conflicts=1, New Position for Row 7 -> Column 7
# Board Position: [0, 4, 4, 0, 6, 7, 3, 7]
# Iteration 103: Temperature=35.52, Current Conflicts=9, Delta Conflicts=1, New Position for Row 6 -> Column 7
# Board Position: [0, 4, 4, 0, 6, 7, 7, 7]
# Iteration 104: Temperature=35.16, Current Conflicts=9, Delta Conflicts=2, New Position for Row 4 -> Column 7
# Board Position: [0, 4, 4, 0, 6, 7, 7, 7]
# Iteration 105: Temperature=34.81, Current Conflicts=11, Delta Conflicts=2, New Position for Row 3 -> Column 3
# Board Position: [0, 4, 4, 3, 6, 7, 7, 7]
# Iteration 106: Temperature=34.46, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 5 -> Column 6
# Board Position: [0, 4, 4, 3, 6, 6, 7, 7]
# Iteration 107: Temperature=34.12, Current Conflicts=11, Delta Conflicts=2, New Position for Row 0 -> Column 6
# Board Position: [6, 4, 4, 3, 6, 6, 7, 7]
# Iteration 108: Temperature=33.78, Current Conflicts=13, Delta Conflicts=2, New Position for Row 7 -> Column 6
# Board Position: [6, 4, 4, 3, 6, 6, 7, 6]
# Iteration 109: Temperature=33.44, Current Conflicts=11, Delta Conflicts=-2, New Position for Row 7 -> Column 7
# Board Position: [6, 4, 4, 3, 6, 6, 7, 7]
# Iteration 110: Temperature=33.10, Current Conflicts=9, Delta Conflicts=-2, New Position for Row 7 -> Column 1
# Board Position: [6, 4, 4, 3, 6, 6, 7, 1]
# Iteration 111: Temperature=32.77, Current Conflicts=9, Delta Conflicts=2, New Position for Row 1 -> Column 3
# Board Position: [6, 4, 4, 3, 6, 6, 7, 1]
# Iteration 112: Temperature=32.44, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 5 -> Column 3
# Board Position: [6, 4, 4, 3, 6, 3, 7, 1]
# Iteration 113: Temperature=32.12, Current Conflicts=9, Delta Conflicts=1, New Position for Row 7 -> Column 4
# Board Position: [6, 4, 4, 3, 6, 3, 7, 4]
# Iteration 114: Temperature=31.80, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 3 -> Column 0
# Board Position: [6, 4, 4, 0, 6, 3, 7, 4]
# Iteration 115: Temperature=31.48, Current Conflicts=8, Delta Conflicts=1, New Position for Row 4 -> Column 2
# Board Position: [6, 4, 4, 0, 2, 3, 7, 4]
# Iteration 116: Temperature=31.17, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 0 -> Column 5
# Board Position: [5, 4, 4, 0, 2, 3, 7, 4]
# Iteration 117: Temperature=30.85, Current Conflicts=8, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [6, 4, 4, 0, 2, 3, 7, 4]
# Iteration 118: Temperature=30.55, Current Conflicts=8, Delta Conflicts=0, New Position for Row 4 -> Column 1
# Board Position: [6, 4, 4, 0, 1, 3, 7, 4]
# Iteration 119: Temperature=30.24, Current Conflicts=11, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [6, 4, 4, 0, 1, 2, 7, 4]
# Iteration 120: Temperature=29.94, Current Conflicts=7, Delta Conflicts=-4, New Position for Row 7 -> Column 1
# Board Position: [6, 4, 4, 0, 1, 2, 7, 1]
# Iteration 121: Temperature=29.64, Current Conflicts=7, Delta Conflicts=0, New Position for Row 0 -> Column 0
# Board Position: [0, 4, 4, 0, 1, 2, 7, 1]
# Iteration 122: Temperature=29.34, Current Conflicts=8, Delta Conflicts=1, New Position for Row 0 -> Column 4
# Board Position: [4, 4, 4, 0, 1, 2, 7, 1]
# Iteration 123: Temperature=29.05, Current Conflicts=8, Delta Conflicts=0, New Position for Row 0 -> Column 7
# Board Position: [7, 4, 4, 0, 1, 2, 7, 1]
# Iteration 124: Temperature=28.76, Current Conflicts=8, Delta Conflicts=0, New Position for Row 0 -> Column 3
# Board Position: [3, 4, 4, 0, 1, 2, 7, 1]
# Iteration 125: Temperature=28.47, Current Conflicts=10, Delta Conflicts=2, New Position for Row 2 -> Column 5
# Board Position: [3, 4, 5, 0, 1, 2, 7, 1]
# Iteration 126: Temperature=28.19, Current Conflicts=8, Delta Conflicts=-2, New Position for Row 5 -> Column 6
# Board Position: [3, 4, 5, 0, 1, 6, 7, 1]
# Iteration 127: Temperature=27.90, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 4 -> Column 6
# Board Position: [3, 4, 5, 0, 6, 6, 7, 1]
# Iteration 128: Temperature=27.63, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 1
# Board Position: [1, 4, 5, 0, 6, 6, 7, 1]
# Iteration 129: Temperature=27.35, Current Conflicts=8, Delta Conflicts=2, New Position for Row 3 -> Column 7
# Board Position: [1, 4, 5, 7, 6, 6, 7, 1]
# Iteration 130: Temperature=27.08, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 0 -> Column 5
# Board Position: [5, 4, 5, 7, 6, 6, 7, 1]
# Iteration 131: Temperature=26.80, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 6 -> Column 0
# Board Position: [5, 4, 5, 7, 6, 6, 0, 1]
# Iteration 132: Temperature=26.54, Current Conflicts=7, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [5, 4, 5, 7, 6, 7, 0, 1]
# Iteration 133: Temperature=26.27, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 6
# Board Position: [5, 4, 5, 7, 6, 7, 0, 6]
# Iteration 134: Temperature=26.01, Current Conflicts=9, Delta Conflicts=2, New Position for Row 5 -> Column 5
# Board Position: [5, 4, 5, 7, 6, 5, 0, 6]
# Iteration 135: Temperature=25.75, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 5 -> Column 4
# Board Position: [5, 4, 5, 7, 6, 4, 0, 6]
# Iteration 136: Temperature=25.49, Current Conflicts=8, Delta Conflicts=1, New Position for Row 4 -> Column 5
# Board Position: [5, 4, 5, 7, 5, 4, 0, 6]
# Iteration 137: Temperature=25.24, Current Conflicts=11, Delta Conflicts=3, New Position for Row 6 -> Column 7
# Board Position: [5, 4, 5, 7, 5, 4, 7, 6]
# Iteration 138: Temperature=24.98, Current Conflicts=11, Delta Conflicts=0, New Position for Row 7 -> Column 7
# Board Position: [5, 4, 5, 7, 5, 4, 7, 7]
# Iteration 139: Temperature=24.73, Current Conflicts=11, Delta Conflicts=0, New Position for Row 7 -> Column 2
# Board Position: [5, 4, 5, 7, 5, 4, 7, 2]
# Iteration 140: Temperature=24.49, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 5 -> Column 6
# Board Position: [5, 4, 5, 7, 5, 6, 7, 2]
# Iteration 141: Temperature=24.24, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 6 -> Column 0
# Board Position: [5, 4, 5, 7, 5, 6, 0, 2]
# Iteration 142: Temperature=24.00, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 0 -> Column 2
# Board Position: [2, 4, 5, 7, 5, 6, 0, 2]
# Iteration 143: Temperature=23.76, Current Conflicts=8, Delta Conflicts=3, New Position for Row 6 -> Column 7
# Board Position: [2, 4, 5, 7, 5, 6, 7, 2]
# Iteration 144: Temperature=23.52, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 5 -> Column 1
# Board Position: [2, 4, 5, 7, 5, 1, 7, 2]
# Iteration 145: Temperature=23.29, Current Conflicts=6, Delta Conflicts=0, New Position for Row 3 -> Column 3
# Board Position: [2, 4, 5, 3, 5, 1, 7, 2]
# Iteration 146: Temperature=23.05, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 4 -> Column 6
# Board Position: [2, 4, 5, 3, 6, 1, 7, 2]
# Iteration 147: Temperature=22.82, Current Conflicts=4, Delta Conflicts=0, New Position for Row 0 -> Column 7
# Board Position: [7, 4, 5, 3, 6, 1, 7, 2]
# Iteration 148: Temperature=22.59, Current Conflicts=5, Delta Conflicts=1, New Position for Row 1 -> Column 2
# Board Position: [7, 2, 5, 3, 6, 1, 7, 2]
# Iteration 149: Temperature=22.37, Current Conflicts=6, Delta Conflicts=1, New Position for Row 3 -> Column 5
# Board Position: [7, 2, 5, 5, 6, 1, 7, 2]
# Iteration 150: Temperature=22.15, Current Conflicts=7, Delta Conflicts=1, New Position for Row 5 -> Column 0
# Board Position: [7, 2, 5, 5, 6, 0, 7, 2]
# Iteration 151: Temperature=21.92, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 6 -> Column 0
# Board Position: [7, 2, 5, 5, 6, 0, 0, 2]
# Iteration 152: Temperature=21.70, Current Conflicts=7, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [7, 2, 5, 5, 6, 5, 0, 2]
# Iteration 153: Temperature=21.49, Current Conflicts=7, Delta Conflicts=0, New Position for Row 5 -> Column 7
# Board Position: [7, 2, 5, 5, 6, 7, 0, 2]
# Iteration 154: Temperature=21.27, Current Conflicts=8, Delta Conflicts=1, New Position for Row 5 -> Column 2
# Board Position: [7, 2, 5, 5, 6, 2, 0, 2]
# Iteration 155: Temperature=21.06, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 0 -> Column 1
# Board Position: [1, 2, 5, 5, 6, 2, 0, 2]
# Iteration 156: Temperature=20.85, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 3 -> Column 1
# Board Position: [1, 2, 5, 1, 6, 2, 0, 2]
# Iteration 157: Temperature=20.64, Current Conflicts=6, Delta Conflicts=5, New Position for Row 6 -> Column 1
# Board Position: [1, 2, 5, 1, 6, 2, 0, 2]
# Iteration 158: Temperature=20.43, Current Conflicts=6, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [1, 2, 5, 1, 6, 2, 0, 2]
# Iteration 159: Temperature=20.23, Current Conflicts=6, Delta Conflicts=0, New Position for Row 5 -> Column 1
# Board Position: [1, 2, 5, 1, 6, 1, 0, 2]
# Iteration 160: Temperature=20.03, Current Conflicts=6, Delta Conflicts=0, New Position for Row 3 -> Column 2
# Board Position: [1, 2, 5, 2, 6, 1, 0, 2]
# Iteration 161: Temperature=19.83, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 1 -> Column 3
# Board Position: [1, 3, 5, 2, 6, 1, 0, 2]
# Iteration 162: Temperature=19.63, Current Conflicts=7, Delta Conflicts=3, New Position for Row 0 -> Column 2
# Board Position: [2, 3, 5, 2, 6, 1, 0, 2]
# Iteration 163: Temperature=19.43, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 7 -> Column 7
# Board Position: [2, 3, 5, 2, 6, 1, 0, 7]
# Iteration 164: Temperature=19.24, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 3, 5, 2, 6, 1, 0, 7]
# Iteration 165: Temperature=19.05, Current Conflicts=5, Delta Conflicts=1, New Position for Row 5 -> Column 2
# Board Position: [0, 3, 5, 2, 6, 2, 0, 7]
# Iteration 166: Temperature=18.86, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 5 -> Column 6
# Board Position: [0, 3, 5, 2, 6, 6, 0, 7]
# Iteration 167: Temperature=18.67, Current Conflicts=6, Delta Conflicts=2, New Position for Row 5 -> Column 0
# Board Position: [0, 3, 5, 2, 6, 0, 0, 7]
# Iteration 168: Temperature=18.48, Current Conflicts=7, Delta Conflicts=1, New Position for Row 7 -> Column 2
# Board Position: [0, 3, 5, 2, 6, 0, 0, 2]
# Iteration 169: Temperature=18.30, Current Conflicts=8, Delta Conflicts=1, New Position for Row 6 -> Column 1
# Board Position: [0, 3, 5, 2, 6, 0, 1, 2]
# Iteration 170: Temperature=18.11, Current Conflicts=9, Delta Conflicts=1, New Position for Row 4 -> Column 5
# Board Position: [0, 3, 5, 2, 5, 0, 1, 2]
# Iteration 171: Temperature=17.93, Current Conflicts=11, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [0, 3, 5, 2, 3, 0, 1, 2]
# Iteration 172: Temperature=17.75, Current Conflicts=11, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 5, 2, 3, 0, 1, 2]
# Iteration 173: Temperature=17.57, Current Conflicts=11, Delta Conflicts=0, New Position for Row 0 -> Column 0
# Board Position: [0, 3, 5, 2, 3, 0, 1, 2]
# Iteration 174: Temperature=17.40, Current Conflicts=8, Delta Conflicts=-3, New Position for Row 3 -> Column 7
# Board Position: [0, 3, 5, 7, 3, 0, 1, 2]
# Iteration 175: Temperature=17.22, Current Conflicts=10, Delta Conflicts=2, New Position for Row 3 -> Column 5
# Board Position: [0, 3, 5, 5, 3, 0, 1, 2]
# Iteration 176: Temperature=17.05, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 4 -> Column 1
# Board Position: [0, 3, 5, 5, 1, 0, 1, 2]
# Iteration 177: Temperature=16.88, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 5 -> Column 3
# Board Position: [0, 3, 5, 5, 1, 3, 1, 2]
# Iteration 178: Temperature=16.71, Current Conflicts=7, Delta Conflicts=0, New Position for Row 1 -> Column 5
# Board Position: [0, 5, 5, 5, 1, 3, 1, 2]
# Iteration 179: Temperature=16.55, Current Conflicts=10, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [0, 5, 5, 5, 1, 2, 1, 2]
# Iteration 180: Temperature=16.38, Current Conflicts=11, Delta Conflicts=1, New Position for Row 0 -> Column 3
# Board Position: [3, 5, 5, 5, 1, 2, 1, 2]
# Iteration 181: Temperature=16.22, Current Conflicts=8, Delta Conflicts=-3, New Position for Row 5 -> Column 7
# Board Position: [3, 5, 5, 5, 1, 7, 1, 2]
# Iteration 182: Temperature=16.05, Current Conflicts=11, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [3, 5, 5, 5, 1, 2, 1, 2]
# Iteration 183: Temperature=15.89, Current Conflicts=12, Delta Conflicts=1, New Position for Row 7 -> Column 5
# Board Position: [3, 5, 5, 5, 1, 2, 1, 5]
# Iteration 184: Temperature=15.74, Current Conflicts=13, Delta Conflicts=1, New Position for Row 0 -> Column 2
# Board Position: [2, 5, 5, 5, 1, 2, 1, 5]
# Iteration 185: Temperature=15.58, Current Conflicts=12, Delta Conflicts=-1, New Position for Row 7 -> Column 4
# Board Position: [2, 5, 5, 5, 1, 2, 1, 4]
# Iteration 186: Temperature=15.42, Current Conflicts=9, Delta Conflicts=-3, New Position for Row 6 -> Column 7
# Board Position: [2, 5, 5, 5, 1, 2, 7, 4]
# Iteration 187: Temperature=15.27, Current Conflicts=9, Delta Conflicts=0, New Position for Row 0 -> Column 1
# Board Position: [1, 5, 5, 5, 1, 2, 7, 4]
# Iteration 188: Temperature=15.12, Current Conflicts=9, Delta Conflicts=0, New Position for Row 1 -> Column 1
# Board Position: [1, 1, 5, 5, 1, 2, 7, 4]
# Iteration 189: Temperature=14.96, Current Conflicts=11, Delta Conflicts=2, New Position for Row 3 -> Column 0
# Board Position: [1, 1, 5, 0, 1, 2, 7, 4]
# Iteration 190: Temperature=14.81, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 5 -> Column 6
# Board Position: [1, 1, 5, 0, 1, 6, 7, 4]
# Iteration 191: Temperature=14.67, Current Conflicts=11, Delta Conflicts=1, New Position for Row 2 -> Column 4
# Board Position: [1, 1, 4, 0, 1, 6, 7, 4]
# Iteration 192: Temperature=14.52, Current Conflicts=11, Delta Conflicts=0, New Position for Row 2 -> Column 6
# Board Position: [1, 1, 6, 0, 1, 6, 7, 4]
# Iteration 193: Temperature=14.37, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 6 -> Column 4
# Board Position: [1, 1, 6, 0, 1, 6, 4, 4]
# Iteration 194: Temperature=14.23, Current Conflicts=10, Delta Conflicts=0, New Position for Row 7 -> Column 1
# Board Position: [1, 1, 6, 0, 1, 6, 4, 1]
# Iteration 195: Temperature=14.09, Current Conflicts=7, Delta Conflicts=-3, New Position for Row 7 -> Column 3
# Board Position: [1, 1, 6, 0, 1, 6, 4, 3]
# Iteration 196: Temperature=13.95, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 5 -> Column 4
# Board Position: [1, 1, 6, 0, 1, 4, 4, 3]
# Iteration 197: Temperature=13.81, Current Conflicts=6, Delta Conflicts=0, New Position for Row 6 -> Column 2
# Board Position: [1, 1, 6, 0, 1, 4, 2, 3]
# Iteration 198: Temperature=13.67, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 4 -> Column 3
# Board Position: [1, 1, 6, 0, 3, 4, 2, 3]
# Iteration 199: Temperature=13.53, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 4 -> Column 2
# Board Position: [1, 1, 6, 0, 2, 4, 2, 3]
# Iteration 200: Temperature=13.40, Current Conflicts=4, Delta Conflicts=3, New Position for Row 3 -> Column 2
# Board Position: [1, 1, 6, 0, 2, 4, 2, 3]
# Iteration 201: Temperature=13.26, Current Conflicts=3, Delta Conflicts=-1, New Position for Row 0 -> Column 7
# Board Position: [7, 1, 6, 0, 2, 4, 2, 3]
# Iteration 202: Temperature=13.13, Current Conflicts=3, Delta Conflicts=0, New Position for Row 7 -> Column 5
# Board Position: [7, 1, 6, 0, 2, 4, 2, 5]
# Iteration 203: Temperature=13.00, Current Conflicts=2, Delta Conflicts=-1, New Position for Row 4 -> Column 6
# Board Position: [7, 1, 6, 0, 6, 4, 2, 5]
# Iteration 204: Temperature=12.87, Current Conflicts=3, Delta Conflicts=1, New Position for Row 5 -> Column 0
# Board Position: [7, 1, 6, 0, 6, 0, 2, 5]
# Iteration 205: Temperature=12.74, Current Conflicts=5, Delta Conflicts=2, New Position for Row 5 -> Column 7
# Board Position: [7, 1, 6, 0, 6, 7, 2, 5]
# Iteration 206: Temperature=12.61, Current Conflicts=5, Delta Conflicts=1, New Position for Row 4 -> Column 4
# Board Position: [7, 1, 6, 0, 6, 7, 2, 5]
# Iteration 207: Temperature=12.49, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 1
# Board Position: [7, 1, 6, 0, 1, 7, 2, 5]
# Iteration 208: Temperature=12.36, Current Conflicts=8, Delta Conflicts=3, New Position for Row 7 -> Column 1
# Board Position: [7, 1, 6, 0, 1, 7, 2, 1]
# Iteration 209: Temperature=12.24, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 7 -> Column 2
# Board Position: [7, 1, 6, 0, 1, 7, 2, 2]
# Iteration 210: Temperature=12.12, Current Conflicts=6, Delta Conflicts=1, New Position for Row 1 -> Column 6
# Board Position: [7, 6, 6, 0, 1, 7, 2, 2]
# Iteration 211: Temperature=12.00, Current Conflicts=7, Delta Conflicts=1, New Position for Row 4 -> Column 7
# Board Position: [7, 6, 6, 0, 7, 7, 2, 2]
# Iteration 212: Temperature=11.88, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 4 -> Column 1
# Board Position: [7, 6, 6, 0, 1, 7, 2, 2]
# Iteration 213: Temperature=11.76, Current Conflicts=7, Delta Conflicts=1, New Position for Row 7 -> Column 6
# Board Position: [7, 6, 6, 0, 1, 7, 2, 6]
# Iteration 214: Temperature=11.64, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 4 -> Column 5
# Board Position: [7, 6, 6, 0, 5, 7, 2, 6]
# Iteration 215: Temperature=11.52, Current Conflicts=6, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [7, 6, 6, 0, 5, 5, 2, 6]
# Iteration 216: Temperature=11.41, Current Conflicts=8, Delta Conflicts=2, New Position for Row 0 -> Column 5
# Board Position: [5, 6, 6, 0, 5, 5, 2, 6]
# Iteration 217: Temperature=11.29, Current Conflicts=8, Delta Conflicts=3, New Position for Row 6 -> Column 6
# Board Position: [5, 6, 6, 0, 5, 5, 2, 6]
# Iteration 218: Temperature=11.18, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 5 -> Column 1
# Board Position: [5, 6, 6, 0, 5, 1, 2, 6]
# Iteration 219: Temperature=11.07, Current Conflicts=8, Delta Conflicts=1, New Position for Row 4 -> Column 4
# Board Position: [5, 6, 6, 0, 4, 1, 2, 6]
# Iteration 220: Temperature=10.96, Current Conflicts=11, Delta Conflicts=3, New Position for Row 0 -> Column 6
# Board Position: [6, 6, 6, 0, 4, 1, 2, 6]
# Iteration 221: Temperature=10.85, Current Conflicts=12, Delta Conflicts=1, New Position for Row 1 -> Column 7
# Board Position: [6, 7, 6, 0, 4, 1, 2, 6]
# Iteration 222: Temperature=10.74, Current Conflicts=16, Delta Conflicts=4, New Position for Row 3 -> Column 5
# Board Position: [6, 7, 6, 5, 4, 1, 2, 6]
# Iteration 223: Temperature=10.63, Current Conflicts=16, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [6, 7, 6, 5, 4, 5, 2, 6]
# Iteration 224: Temperature=10.53, Current Conflicts=15, Delta Conflicts=-1, New Position for Row 5 -> Column 2
# Board Position: [6, 7, 6, 5, 4, 2, 2, 6]
# Iteration 225: Temperature=10.42, Current Conflicts=10, Delta Conflicts=-5, New Position for Row 2 -> Column 1
# Board Position: [6, 7, 1, 5, 4, 2, 2, 6]
# Iteration 226: Temperature=10.32, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 0 -> Column 5
# Board Position: [5, 7, 1, 5, 4, 2, 2, 6]
# Iteration 227: Temperature=10.21, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 6 -> Column 3
# Board Position: [5, 7, 1, 5, 4, 2, 3, 6]
# Iteration 228: Temperature=10.11, Current Conflicts=7, Delta Conflicts=1, New Position for Row 1 -> Column 6
# Board Position: [5, 6, 1, 5, 4, 2, 3, 6]
# Iteration 229: Temperature=10.01, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 1 -> Column 0
# Board Position: [5, 0, 1, 5, 4, 2, 3, 6]
# Iteration 230: Temperature=9.91, Current Conflicts=6, Delta Conflicts=0, New Position for Row 6 -> Column 4
# Board Position: [5, 0, 1, 5, 4, 2, 4, 6]
# Iteration 231: Temperature=9.81, Current Conflicts=6, Delta Conflicts=0, New Position for Row 1 -> Column 2
# Board Position: [5, 2, 1, 5, 4, 2, 4, 6]
# Iteration 232: Temperature=9.71, Current Conflicts=7, Delta Conflicts=1, New Position for Row 3 -> Column 0
# Board Position: [5, 2, 1, 0, 4, 2, 4, 6]
# Iteration 233: Temperature=9.62, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 2 -> Column 6
# Board Position: [5, 2, 6, 0, 4, 2, 4, 6]
# Iteration 234: Temperature=9.52, Current Conflicts=7, Delta Conflicts=1, New Position for Row 2 -> Column 2
# Board Position: [5, 2, 2, 0, 4, 2, 4, 6]
# Iteration 235: Temperature=9.42, Current Conflicts=9, Delta Conflicts=2, New Position for Row 7 -> Column 0
# Board Position: [5, 2, 2, 0, 4, 2, 4, 0]
# Iteration 236: Temperature=9.33, Current Conflicts=9, Delta Conflicts=0, New Position for Row 1 -> Column 6
# Board Position: [5, 6, 2, 0, 4, 2, 4, 0]
# Iteration 237: Temperature=9.24, Current Conflicts=9, Delta Conflicts=0, New Position for Row 0 -> Column 6
# Board Position: [6, 6, 2, 0, 4, 2, 4, 0]
# Iteration 238: Temperature=9.14, Current Conflicts=5, Delta Conflicts=-4, New Position for Row 5 -> Column 7
# Board Position: [6, 6, 2, 0, 4, 7, 4, 0]
# Iteration 239: Temperature=9.05, Current Conflicts=5, Delta Conflicts=0, New Position for Row 6 -> Column 7
# Board Position: [6, 6, 2, 0, 4, 7, 7, 0]
# Iteration 240: Temperature=8.96, Current Conflicts=6, Delta Conflicts=1, New Position for Row 6 -> Column 2
# Board Position: [6, 6, 2, 0, 4, 7, 2, 0]
# Iteration 241: Temperature=8.87, Current Conflicts=4, Delta Conflicts=-2, New Position for Row 2 -> Column 3
# Board Position: [6, 6, 3, 0, 4, 7, 2, 0]
# Iteration 242: Temperature=8.78, Current Conflicts=7, Delta Conflicts=3, New Position for Row 3 -> Column 4
# Board Position: [6, 6, 3, 4, 4, 7, 2, 0]
# Iteration 243: Temperature=8.70, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 1 -> Column 3
# Board Position: [6, 3, 3, 4, 4, 7, 2, 0]
# Iteration 244: Temperature=8.61, Current Conflicts=7, Delta Conflicts=1, New Position for Row 2 -> Column 6
# Board Position: [6, 3, 6, 4, 4, 7, 2, 0]
# Iteration 245: Temperature=8.52, Current Conflicts=8, Delta Conflicts=1, New Position for Row 7 -> Column 3
# Board Position: [6, 3, 6, 4, 4, 7, 2, 3]
# Iteration 246: Temperature=8.44, Current Conflicts=11, Delta Conflicts=3, New Position for Row 0 -> Column 4
# Board Position: [4, 3, 6, 4, 4, 7, 2, 3]
# Iteration 247: Temperature=8.35, Current Conflicts=8, Delta Conflicts=-3, New Position for Row 4 -> Column 5
# Board Position: [4, 3, 6, 4, 5, 7, 2, 3]
# Iteration 248: Temperature=8.27, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 7 -> Column 0
# Board Position: [4, 3, 6, 4, 5, 7, 2, 0]
# Iteration 249: Temperature=8.19, Current Conflicts=7, Delta Conflicts=0, New Position for Row 5 -> Column 1
# Board Position: [4, 3, 6, 4, 5, 1, 2, 0]
# Iteration 250: Temperature=8.11, Current Conflicts=5, Delta Conflicts=-2, New Position for Row 3 -> Column 0
# Board Position: [4, 3, 6, 0, 5, 1, 2, 0]
# Iteration 251: Temperature=8.02, Current Conflicts=5, Delta Conflicts=0, New Position for Row 2 -> Column 3
# Board Position: [4, 3, 3, 0, 5, 1, 2, 0]
# Iteration 252: Temperature=7.94, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 2 -> Column 7
# Board Position: [4, 3, 7, 0, 5, 1, 2, 0]
# Iteration 253: Temperature=7.87, Current Conflicts=5, Delta Conflicts=1, New Position for Row 0 -> Column 7
# Board Position: [7, 3, 7, 0, 5, 1, 2, 0]
# Iteration 254: Temperature=7.79, Current Conflicts=6, Delta Conflicts=1, New Position for Row 4 -> Column 2
# Board Position: [7, 3, 7, 0, 2, 1, 2, 0]
# Iteration 255: Temperature=7.71, Current Conflicts=6, Delta Conflicts=0, New Position for Row 5 -> Column 0
# Board Position: [7, 3, 7, 0, 2, 0, 2, 0]
# Iteration 256: Temperature=7.63, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 3
# Board Position: [3, 3, 7, 0, 2, 0, 2, 0]
# Iteration 257: Temperature=7.56, Current Conflicts=6, Delta Conflicts=0, New Position for Row 5 -> Column 7
# Board Position: [3, 3, 7, 0, 2, 7, 2, 0]
# Iteration 258: Temperature=7.48, Current Conflicts=7, Delta Conflicts=1, New Position for Row 7 -> Column 5
# Board Position: [3, 3, 7, 0, 2, 7, 2, 5]
# Iteration 259: Temperature=7.40, Current Conflicts=8, Delta Conflicts=1, New Position for Row 6 -> Column 4
# Board Position: [3, 3, 7, 0, 2, 7, 4, 5]
# Iteration 260: Temperature=7.33, Current Conflicts=8, Delta Conflicts=0, New Position for Row 7 -> Column 3
# Board Position: [3, 3, 7, 0, 2, 7, 4, 3]
# Iteration 261: Temperature=7.26, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 6 -> Column 5
# Board Position: [3, 3, 7, 0, 2, 7, 5, 3]
# Iteration 262: Temperature=7.18, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 5 -> Column 6
# Board Position: [3, 3, 7, 0, 2, 6, 5, 3]
# Iteration 263: Temperature=7.11, Current Conflicts=9, Delta Conflicts=4, New Position for Row 4 -> Column 7
# Board Position: [3, 3, 7, 0, 7, 6, 5, 3]
# Iteration 264: Temperature=7.04, Current Conflicts=6, Delta Conflicts=-3, New Position for Row 0 -> Column 6
# Board Position: [6, 3, 7, 0, 7, 6, 5, 3]
# Iteration 265: Temperature=6.97, Current Conflicts=7, Delta Conflicts=1, New Position for Row 0 -> Column 7
# Board Position: [7, 3, 7, 0, 7, 6, 5, 3]
# Iteration 266: Temperature=6.90, Current Conflicts=8, Delta Conflicts=1, New Position for Row 2 -> Column 5
# Board Position: [7, 3, 5, 0, 7, 6, 5, 3]
# Iteration 267: Temperature=6.83, Current Conflicts=9, Delta Conflicts=1, New Position for Row 1 -> Column 2
# Board Position: [7, 2, 5, 0, 7, 6, 5, 3]
# Iteration 268: Temperature=6.76, Current Conflicts=9, Delta Conflicts=2, New Position for Row 7 -> Column 5
# Board Position: [7, 2, 5, 0, 7, 6, 5, 3]
# Iteration 269: Temperature=6.70, Current Conflicts=7, Delta Conflicts=-2, New Position for Row 2 -> Column 0
# Board Position: [7, 2, 0, 0, 7, 6, 5, 3]
# Iteration 270: Temperature=6.63, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 5 -> Column 7
# Board Position: [7, 2, 0, 0, 7, 7, 5, 3]
# Iteration 271: Temperature=6.56, Current Conflicts=6, Delta Conflicts=0, New Position for Row 1 -> Column 4
# Board Position: [7, 4, 0, 0, 7, 7, 5, 3]
# Iteration 272: Temperature=6.50, Current Conflicts=8, Delta Conflicts=2, New Position for Row 1 -> Column 7
# Board Position: [7, 7, 0, 0, 7, 7, 5, 3]
# Iteration 273: Temperature=6.43, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 4 -> Column 5
# Board Position: [7, 7, 0, 0, 5, 7, 5, 3]
# Iteration 274: Temperature=6.37, Current Conflicts=7, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [7, 7, 0, 0, 3, 7, 5, 3]
# Iteration 275: Temperature=6.30, Current Conflicts=8, Delta Conflicts=1, New Position for Row 6 -> Column 0
# Board Position: [7, 7, 0, 0, 3, 7, 0, 3]
# Iteration 276: Temperature=6.24, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 4
# Board Position: [7, 7, 0, 4, 3, 7, 0, 3]
# Iteration 277: Temperature=6.18, Current Conflicts=8, Delta Conflicts=0, New Position for Row 2 -> Column 1
# Board Position: [7, 7, 1, 4, 3, 7, 0, 3]
# Iteration 278: Temperature=6.12, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 4 -> Column 4
# Board Position: [7, 7, 1, 4, 4, 7, 0, 3]
# Iteration 279: Temperature=6.06, Current Conflicts=7, Delta Conflicts=1, New Position for Row 6 -> Column 3
# Board Position: [7, 7, 1, 4, 4, 7, 3, 3]
# Iteration 280: Temperature=6.00, Current Conflicts=7, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [7, 7, 1, 4, 4, 7, 3, 3]
# Iteration 281: Temperature=5.94, Current Conflicts=6, Delta Conflicts=-1, New Position for Row 1 -> Column 1
# Board Position: [7, 1, 1, 4, 4, 7, 3, 3]
# Iteration 282: Temperature=5.88, Current Conflicts=6, Delta Conflicts=2, New Position for Row 2 -> Column 4
# Board Position: [7, 1, 1, 4, 4, 7, 3, 3]
# Iteration 283: Temperature=5.82, Current Conflicts=6, Delta Conflicts=0, New Position for Row 4 -> Column 7
# Board Position: [7, 1, 1, 4, 7, 7, 3, 3]
# Iteration 284: Temperature=5.76, Current Conflicts=6, Delta Conflicts=3, New Position for Row 2 -> Column 7
# Board Position: [7, 1, 1, 4, 7, 7, 3, 3]
# Iteration 285: Temperature=5.70, Current Conflicts=8, Delta Conflicts=2, New Position for Row 1 -> Column 7
# Board Position: [7, 7, 1, 4, 7, 7, 3, 3]
# Iteration 286: Temperature=5.65, Current Conflicts=8, Delta Conflicts=5, New Position for Row 2 -> Column 7
# Board Position: [7, 7, 1, 4, 7, 7, 3, 3]
# Iteration 287: Temperature=5.59, Current Conflicts=8, Delta Conflicts=0, New Position for Row 3 -> Column 2
# Board Position: [7, 7, 1, 2, 7, 7, 3, 3]
# Iteration 288: Temperature=5.53, Current Conflicts=7, Delta Conflicts=-1, New Position for Row 1 -> Column 0
# Board Position: [7, 0, 1, 2, 7, 7, 3, 3]
# Iteration 289: Temperature=5.48, Current Conflicts=7, Delta Conflicts=0, New Position for Row 1 -> Column 2
# Board Position: [7, 2, 1, 2, 7, 7, 3, 3]
# Iteration 290: Temperature=5.42, Current Conflicts=10, Delta Conflicts=3, New Position for Row 6 -> Column 7
# Board Position: [7, 2, 1, 2, 7, 7, 7, 3]
# Iteration 291: Temperature=5.37, Current Conflicts=9, Delta Conflicts=-1, New Position for Row 1 -> Column 3
# Board Position: [7, 3, 1, 2, 7, 7, 7, 3]
# Iteration 292: Temperature=5.31, Current Conflicts=9, Delta Conflicts=0, New Position for Row 1 -> Column 4
# Board Position: [7, 4, 1, 2, 7, 7, 7, 3]
# Iteration 293: Temperature=5.26, Current Conflicts=8, Delta Conflicts=-1, New Position for Row 3 -> Column 5
# Board Position: [7, 4, 1, 5, 7, 7, 7, 3]
# Iteration 294: Temperature=5.21, Current Conflicts=6, Delta Conflicts=-2, New Position for Row 4 -> Column 4
# Board Position: [7, 4, 1, 5, 4, 7, 7, 3]
# Iteration 295: Temperature=5.16, Current Conflicts=6, Delta Conflicts=3, New Position for Row 2 -> Column 3
# Board Position: [7, 4, 1, 5, 4, 7, 7, 3]
# Iteration 296: Temperature=5.11, Current Conflicts=6, Delta Conflicts=0, New Position for Row 0 -> Column 1
# Board Position: [1, 4, 1, 5, 4, 7, 7, 3]
# Iteration 297: Temperature=5.05, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 2 -> Column 0
# Board Position: [1, 4, 0, 5, 4, 7, 7, 3]
# Iteration 298: Temperature=5.00, Current Conflicts=5, Delta Conflicts=0, New Position for Row 5 -> Column 1
# Board Position: [1, 4, 0, 5, 4, 1, 7, 3]
# Iteration 299: Temperature=4.95, Current Conflicts=5, Delta Conflicts=0, New Position for Row 4 -> Column 2
# Board Position: [1, 4, 0, 5, 2, 1, 7, 3]
# Iteration 300: Temperature=4.90, Current Conflicts=8, Delta Conflicts=3, New Position for Row 6 -> Column 2
# Board Position: [1, 4, 0, 5, 2, 1, 2, 3]
# Iteration 301: Temperature=4.86, Current Conflicts=5, Delta Conflicts=-3, New Position for Row 6 -> Column 5
# Board Position: [1, 4, 0, 5, 2, 1, 5, 3]
# Iteration 302: Temperature=4.81, Current Conflicts=8, Delta Conflicts=3, New Position for Row 3 -> Column 1
# Board Position: [1, 4, 0, 1, 2, 1, 5, 3]
# Iteration 303: Temperature=4.76, Current Conflicts=11, Delta Conflicts=3, New Position for Row 7 -> Column 5
# Board Position: [1, 4, 0, 1, 2, 1, 5, 5]
# Iteration 304: Temperature=4.71, Current Conflicts=10, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 4, 0, 1, 2, 1, 5, 5]
# Iteration 305: Temperature=4.66, Current Conflicts=11, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [0, 4, 0, 1, 2, 5, 5, 5]
# Iteration 306: Temperature=4.62, Current Conflicts=14, Delta Conflicts=3, New Position for Row 1 -> Column 0
# Board Position: [0, 0, 0, 1, 2, 5, 5, 5]
# Iteration 307: Temperature=4.57, Current Conflicts=11, Delta Conflicts=-3, New Position for Row 1 -> Column 6
# Board Position: [0, 6, 0, 1, 2, 5, 5, 5]
# Iteration 308: Temperature=4.53, Current Conflicts=7, Delta Conflicts=-4, New Position for Row 7 -> Column 2
# Board Position: [0, 6, 0, 1, 2, 5, 5, 2]
# Iteration 309: Temperature=4.48, Current Conflicts=7, Delta Conflicts=0, New Position for Row 7 -> Column 4
# Board Position: [0, 6, 0, 1, 2, 5, 5, 4]
# Iteration 310: Temperature=4.44, Current Conflicts=7, Delta Conflicts=0, New Position for Row 4 -> Column 6
# Board Position: [0, 6, 0, 1, 6, 5, 5, 4]
# Iteration 311: Temperature=4.39, Current Conflicts=9, Delta Conflicts=2, New Position for Row 6 -> Column 6
# Board Position: [0, 6, 0, 1, 6, 5, 6, 4]
# Iteration 312: Temperature=4.35, Current Conflicts=5, Delta Conflicts=-4, New Position for Row 6 -> Column 2
# Board Position: [0, 6, 0, 1, 6, 5, 2, 4]
# Iteration 313: Temperature=4.30, Current Conflicts=4, Delta Conflicts=-1, New Position for Row 0 -> Column 7
# Board Position: [7, 6, 0, 1, 6, 5, 2, 4]
# Iteration 314: Temperature=4.26, Current Conflicts=4, Delta Conflicts=2, New Position for Row 7 -> Column 7
# Board Position: [7, 6, 0, 1, 6, 5, 2, 4]
# Iteration 315: Temperature=4.22, Current Conflicts=5, Delta Conflicts=1, New Position for Row 0 -> Column 4
# Board Position: [4, 6, 0, 1, 6, 5, 2, 4]
# Iteration 316: Temperature=4.18, Current Conflicts=5, Delta Conflicts=0, New Position for Row 2 -> Column 7
# Board Position: [4, 6, 7, 1, 6, 5, 2, 4]
# Iteration 317: Temperature=4.13, Current Conflicts=6, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [4, 6, 7, 1, 6, 7, 2, 4]
# Iteration 318: Temperature=4.09, Current Conflicts=5, Delta Conflicts=-1, New Position for Row 3 -> Column 3
# Board Position: [4, 6, 7, 3, 6, 7, 2, 4]
# Iteration 319: Temperature=4.05, Current Conflicts=5, Delta Conflicts=0, New Position for Row 5 -> Column 5
# Board Position: [4, 6, 7, 3, 6, 5, 2, 4]
# ...
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1127: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 6
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1128: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 2
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1129: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 3 -> Column 7
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1130: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 3
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1131: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 4
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1132: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 6
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1133: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 4 -> Column 4
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1134: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 3
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1135: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 4
# Board Position: [2, 6, 3, 0, 7, 1, 4, 7]
# Iteration 1136: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 7 -> Column 2
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1137: Temperature=0.00, Current Conflicts=1, Delta Conflicts=4, New Position for Row 5 -> Column 2
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1138: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 0
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1139: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1140: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 3 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1141: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1142: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 7 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1143: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 6 -> Column 0
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1144: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1145: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1146: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1147: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 5 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1148: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1149: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1150: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1151: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 6 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1152: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 0 -> Column 2
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1153: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 3
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1154: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 2 -> Column 6
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1155: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 7
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1156: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 1
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1157: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 0
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1158: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 6
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1159: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 1 -> Column 1
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1160: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 5
# Board Position: [2, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1161: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 0 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1162: Temperature=0.00, Current Conflicts=1, Delta Conflicts=4, New Position for Row 3 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1163: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 3 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1164: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1165: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1166: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 3 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1167: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1168: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1169: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1170: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 0
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1171: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1172: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1173: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1174: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1175: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1176: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1177: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 5 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1178: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1179: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 4 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1180: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 6 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1181: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1182: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1183: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1184: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 1 -> Column 0
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1185: Temperature=0.00, Current Conflicts=1, Delta Conflicts=4, New Position for Row 4 -> Column 0
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1186: Temperature=0.00, Current Conflicts=1, Delta Conflicts=4, New Position for Row 4 -> Column 0
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1187: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 5
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1188: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 6
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1189: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 3
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1190: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 3
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1191: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 6 -> Column 4
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1192: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 5
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1193: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 4 -> Column 6
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1194: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1195: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 7 -> Column 1
# Board Position: [4, 0, 3, 0, 7, 1, 6, 2]
# Iteration 1196: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 1 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1197: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1198: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 1 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1199: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 2 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 6, 2]
# Iteration 1200: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 6 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1201: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 1 -> Column 0
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1202: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1203: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 1 -> Column 2
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1204: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1205: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 2 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1206: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 7 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1207: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 3 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1208: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 0
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1209: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 5 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1210: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1211: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 6 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1212: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 5 -> Column 5
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1213: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 6 -> Column 0
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1214: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 0 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1215: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 3 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1216: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 0 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 5, 2]
# Iteration 1217: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 6 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1218: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1219: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1220: Temperature=0.00, Current Conflicts=1, Delta Conflicts=4, New Position for Row 3 -> Column 4
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1221: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1222: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 6
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1223: Temperature=0.00, Current Conflicts=1, Delta Conflicts=2, New Position for Row 4 -> Column 3
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1224: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 7 -> Column 7
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1225: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 1 -> Column 1
# Board Position: [4, 6, 3, 0, 7, 1, 4, 2]
# Iteration 1226: Temperature=0.00, Current Conflicts=1, Delta Conflicts=0, New Position for Row 3 -> Column 5
# Board Position: [4, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1227: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 4 -> Column 5
# Board Position: [4, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1228: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 2
# Board Position: [4, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1229: Temperature=0.00, Current Conflicts=1, Delta Conflicts=3, New Position for Row 7 -> Column 4
# Board Position: [4, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1230: Temperature=0.00, Current Conflicts=1, Delta Conflicts=1, New Position for Row 0 -> Column 1
# Board Position: [4, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1231: Temperature=0.00, Current Conflicts=0, Delta Conflicts=-1, New Position for Row 0 -> Column 0
# Board Position: [0, 6, 3, 5, 7, 1, 4, 2]
# Iteration 1232: Solution found!
# Board Position: [0, 6, 3, 5, 7, 1, 4, 2]
# Final Solution: [0, 6, 3, 5, 7, 1, 4, 2]
